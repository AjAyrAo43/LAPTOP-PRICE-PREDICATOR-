# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/laptop.csv')
df
# Out:
#       Unnamed: 0    Brand                                               Name  \
# 0              0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1              1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2              3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3              4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4              6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# ...          ...      ...                                                ...
# 3971        4403     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...
# 3972        4404     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...
# 3973        4405     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...
# 3974        4407     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...
# 3975        4408   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...
#
# ...

# %%
df.shape
# Out:
# (3976, 18)

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       Unnamed: 0    Brand                                               Name  \
# 0              0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1              1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2              3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3              4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4              6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# ...          ...      ...                                                ...
# 3971        4403     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...
# 3972        4404     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...
# 3973        4405     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...
# 3974        4407     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...
# 3975        4408   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0    Brand                                               Name  \
# 0              0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1              1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2              3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3              4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4              6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# ...          ...      ...                                                ...
# 3971        4403     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...
# 3972        4404     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...
# 3973        4405     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...
# 3974        4407     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...
# 3975        4408   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head(5)
# Out:
#      Brand                                               Name  Price  \
# 0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
#
#              Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0        MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2  Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3  Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4  Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
#
#        RAM_TYPE                 Ghz Display_type Display  \
# 0      DDR4 RAM   2.0 Ghz Processor          LED   11.6
# ...

# %%
df['RAM']=df['RAM'].str.replace('GB','')
df['RAM']=df['RAM'].str.replace('LP','')

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable   RAM  \
# ...

# %%
df['RAM'] = df['RAM'].str.replace('GB', '', regex=False).str.replace('LP', '', regex=False).str.replace('RAM', '', regex=False).str.strip().astype('int32')

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
si_battery_life = SimpleImputer(strategy='most_frequent')
df['Battery_Life'] = si_battery_life.fit_transform(df[['Battery_Life']]).ravel()

# %%
df.isnull().sum()
# Out:
# Brand              0
# Name               0
# Price              0
# Processor_Name     0
# Processor_Brand    0
# RAM_Expandable     0
# RAM                0
# RAM_TYPE           0
# Ghz                0
# Display_type       0
# Display            0
# GPU                8
# GPU_Brand          4
# SSD                0
# HDD                0
# Adapter            0
# Battery_Life       0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# /tmp/ipython-input-834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
sns.barplot(x=df['Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Processor_Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Processor_Brand'>

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# ...

# %%
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RAM'>

# %%
df['Display_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Display_type'>

# %%
sns.barplot(x=df['Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Laptop Data Profiling Report")
profile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.7/398.7 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 4.2 MB/s eta 0:00:00
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3971    False
# 3972    False
# 3973    False
# 3974    False
# 3975    False
# Length: 3976, dtype: bool

# %%
df.isnull().sum()
# Out:
# Brand              0
# Name               0
# Price              0
# Processor_Name     0
# Processor_Brand    0
# RAM_Expandable     0
# RAM                0
# RAM_TYPE           0
# Ghz                0
# Display_type       0
# Display            0
# GPU                8
# GPU_Brand          4
# SSD                0
# HDD                0
# Adapter            0
# Battery_Life       0
# dtype: int64

# %%
sns.scatterplot(x=df['Display'],y=df['Price'])
# Out:
# <Axes: xlabel='Display', ylabel='Price'>

# %%
sns.barplot(x=df['Display_type'],y=df['Price'])
# Out:
# <Axes: xlabel='Display_type', ylabel='Price'>

# %%
df['Ghz']=df['Ghz'].str.replace('Ghz Processor', '')

# %%
df['Adapter']=df['Adapter'].str.replace('no', df['Adapter'].mode()[0])

# %%
df['Ghz']=df['Ghz'].astype('float32')

# %%
df['Adapter']=df['Adapter'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3976 non-null   object
#  1   Name             3976 non-null   object
#  2   Price            3976 non-null   int64
#  3   Processor_Name   3976 non-null   object
#  4   Processor_Brand  3976 non-null   object
#  5   RAM_Expandable   3976 non-null   object
#  6   RAM              3976 non-null   int32
#  7   RAM_TYPE         3976 non-null   object
#  8   Ghz              3976 non-null   float32
#  9   Display_type     3976 non-null   object
#  10  Display          3976 non-null   object
#  11  GPU              3968 non-null   object
#  12  GPU_Brand        3972 non-null   object
#  13  SSD              3976 non-null   object
#  14  HDD              3976 non-null   object
#  15  Adapter          3976 non-null   int32
# ...

# %%
df['Display'] = pd.to_numeric(df['Display'], errors='coerce').astype('float32')

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# ...

# %%
df['SSD'] = pd.to_numeric(df['SSD'], errors='coerce').fillna(0).astype('int32')

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3976 non-null   object
#  1   Name             3976 non-null   object
#  2   Price            3976 non-null   int64
#  3   Processor_Name   3976 non-null   object
#  4   Processor_Brand  3976 non-null   object
#  5   RAM_Expandable   3976 non-null   object
#  6   RAM              3976 non-null   int32
#  7   RAM_TYPE         3976 non-null   object
#  8   Ghz              3976 non-null   float32
#  9   Display_type     3976 non-null   object
#  10  Display          3975 non-null   float32
#  11  GPU              3968 non-null   object
#  12  GPU_Brand        3972 non-null   object
#  13  SSD              3976 non-null   int32
#  14  HDD              3976 non-null   object
#  15  Adapter          3976 non-null   int32
# ...

# %%
df['HDD'].value_counts()
# Out:
# HDD
# No HDD                  3014
# 1024 GB HDD Storage      602
#  1024 GB HDD Storage     294
# 500 GB HDD Storage        43
# 2048 GB HDD Storage       18
#  500 GB HDD Storage        3
#  2048 GB HDD Storage       1
# 1 GB HDD Storage           1
# Name: count, dtype: int64

# %%
df['HDD']=df['HDD'].str.replace('GB HDD Storage', '', regex=False)
df['HDD']=df['HDD'].str.replace('NO HDD', '0', regex=False)
df['HDD'] = pd.to_numeric(df['HDD'], errors='coerce').fillna(0).astype('int32')

# %%
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# ...

# %%
sns.distplot(np.log(df['Price']))
# Out:
# /tmp/ipython-input-3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#         Brand                                               Name  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# ...       ...                                                ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# 0           MediaTek Octa-core        MediaTek     Not Expandable    4
# ...

# %%
y
# Out:
# 0       10.042815
# 1       10.499270
# 2       11.270854
# 3       10.923958
# 4        9.998343
#           ...
# 3971    11.350289
# 3972    10.597409
# 3973    11.238357
# 3974    11.183157
# 3975    11.156108
# Name: Price, Length: 3976, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#      Brand                                               Name  \
# 2864  ASUS  ASUS VivoBook 15 M509DA-EJ542T Laptop (15.6 In...
# 587   ASUS  ASUS TUF Gaming F15 FX566HM-AZ096TS Laptop (15...
# 3786   MSI  MSI GL63 9SDK-802IN Laptop (15.6 Inch | Core i...
# 204   ASUS  ASUS VivoBook 15 X515JA-BQ302W Laptop (15.6 In...
# 1394  Dell  Dell Inspiron 15 3593 (D560105WIN9) Laptop (15...
# ...    ...                                                ...
# 3606  Acer  Acer Aspire Switch Alpha SA5-271 (NT.GDQSI.014...
# 1608    HP  HP 15q-ds0004TX (4ST57PA) Laptop (15.6 Inch | ...
# 2541   MSI  MSI Raider 18 HX A14VHG-254IN Laptop (18 Inch ...
# 2575    HP  HP 14-hr0000AU (8H9G3PA) Laptop (14 Inch | AMD...
# 3240  Acer  Acer Aspire A515-51G (NX.GUGSI.001) Laptop (15...
#
#                 Processor_Name Processor_Brand     RAM_Expandable  RAM  \
# 2864     AMD Quad-Core Ryzen 5             AMD   12 GB Expandable    4
# 587   Intel Core i9 (11th Gen)           Intel   32 GB Expandable   16
# ...

# %%
y_train
# Out:
# 2864    10.490996
# 587     11.542387
# 3786    11.805520
# 204     10.596385
# 1394    10.689647
#           ...
# 3606    10.645187
# 1608    10.839385
# 2541    12.736671
# 2575    10.991831
# 3240    10.968181
# Name: Price, Length: 3379, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
numerical_cols = ['RAM', 'Ghz', 'Display', 'SSD', 'HDD', 'Adapter']
categorical_cols = ['Brand', 'Processor_Name', 'Processor_Brand', 'RAM_Expandable', 'RAM_TYPE', 'Display_type', 'GPU', 'GPU_Brand', 'Battery_Life']

numerical_transformer = SimpleImputer(strategy='mean')
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ],
    remainder='drop'
)

# %% [markdown]
# LINEAR REGRESSION

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', LinearRegression())])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8441396512668986
# MAE 0.16882950085713078

# %% [markdown]
# RIDGE REGRESSION

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', Ridge(alpha=10))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8339240124469307
# MAE 0.18279906473710886

# %% [markdown]
# LASSO REGRESSION

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', Lasso(alpha=0.001))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")

# %% [markdown]
# KNN

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', KNeighborsRegressor(n_neighbors=3))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7799005702872027
# MAE 0.20001477076628463

# %% [markdown]
# Decision Tree

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', DecisionTreeRegressor(max_depth=8))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8023097139384182
# MAE 0.20487297698044704

# %% [markdown]
# SVM

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', SVR(kernel='rbf',C=10000,epsilon=0.1))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8656760720369967
# MAE 0.16023211056684183

# %% [markdown]
# RANDOM FOREST

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8549700883708213
# MAE 0.16796193000329798

# %% [markdown]
# ADABOOST

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', AdaBoostRegressor(n_estimators=15,learning_rate=1.0))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7463311196124249
# MAE 0.23931101332513635

# %% [markdown]
# GADIENT BOOST

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', GradientBoostingRegressor(n_estimators=500))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8662541027381744
# MAE 0.16120905430527646

# %% [markdown]
# XgBOOST

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5))])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.873805370325246
# MAE 0.15854464977998137

# %% [markdown]
# VOTING REGRESSOR

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('step2', step2)])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.862825417361449
# MAE 0.165637821942827

# %% [markdown]
# Stacking

# %%
estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('step2', step2)])

pipe.fit(X_train, y_train)
print("Pipeline fitting complete.")
# Out:
# Pipeline fitting complete.

# %%
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8612893000056485
# MAE 0.16810357214894434

# %% [markdown]
# Exporting the model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import numpy as np
import pandas as pd

# --- Define your laptop specifications below by selecting from the options or entering values ---
# For categorical features, choose one of the options provided in the comments.
# For numerical features, enter a suitable value.

sample_input = pd.DataFrame({
    'Brand': ['HP'], # Options: ['ASUS', 'Lenovo', 'HP', 'Dell', 'Acer', 'MSI', 'Samsung', 'Apple', 'Infinix', 'Microsoft', 'AVITA', 'Gigabyte', 'LG', 'Honor', 'iball', 'Xiaomi', 'Fujitsu', 'Zebronics', 'Wings', 'Colorful', 'Realme', 'Micromax', 'Coconics', 'Tecno', 'Smartron', 'Huawei', 'Razer', 'VAIO', 'Lava', 'Nokia', 'RDP']
    'Name': ['HP Pavilion Aero 13-be0205AU Laptop (AMD Ryzen 5/16GB/512GB SSD/Windows 10)'], # Enter the full name of the laptop
    'Processor_Name': ['AMD Hexa-Core Ryzen 5'], # Example: 'Intel Core i5 (12th Gen)', 'AMD Octa-Core Ryzen 7'
    'Processor_Brand': ['AMD'], # Options: ['Intel', 'AMD', 'MediaTek', 'Apple', 'Qualcomm', 'Microsoft']
    'RAM_Expandable': ['Not Expandable'], # Options: ['Not Expandable', '12 GB Expandable', '32 GB Expandable', '8 GB Expandable', '16 GB Expandable', '64 GB Expandable']
    'RAM': [16], # Enter RAM in GB (e.g., 4, 8, 16, 32)
    'RAM_TYPE': ['DDR4 RAM'], # Options: ['DDR4 RAM', 'DDR5 RAM', 'LPDDR4X RAM', 'DDR3 RAM', 'LPDDR5 RAM', 'LPDDR4 RAM', 'LPDDR3 RAM', 'SSD', 'DDR4', 'LPDDR', ' DDR4 RAM', 'DDR4 ', 'DDR3', 'DDR5', 'DDR3L']
    'Ghz': [2.1], # Enter processor speed in GHz (e.g., 2.0, 4.0, 3.3)
    'Display_type': ['LED'], # Options: ['LED', 'LCD']
    'Display': [13.3], # Enter display size in inches (e.g., 11.6, 15.6, 14.0)
    'GPU': ['Integrated Graphics'], # Example: 'Integrated Graphics', 'GeForce RTX 3050 GPU, 4 GB', 'Iris Xe'
    'GPU_Brand': ['AMD'], # Options: ['MediaTek', 'AMD', 'NVIDIA', 'Intel', 'Apple', 'ARM', 'Qualcomm', 'Microsoft']
    'SSD': [512], # Enter SSD storage in GB (e.g., 64, 256, 512, 1024)
    'HDD': [0], # Enter HDD storage in GB (e.g., 0 for No HDD, 1024)
    'Adapter': [65], # Enter Adapter wattage (e.g., 45, 65, 120, 150)
    'Battery_Life': ['Upto 10 Hrs Battery Life'] # Example: 'Upto 12 Hrs Battery Life', 'Upto 11 Hrs Battery Life', '65W Adapter'
})

# Make a prediction using the trained pipeline
predicted_log_price = pipe.predict(sample_input)

# Inverse transform the log-predicted price to get the actual price
predicted_price = np.exp(predicted_log_price)

print(f"Predicted price for the sample laptop: ₹{predicted_price[0]:,.2f}")
# Out:
# Predicted price for the sample laptop: ₹80,725.52

# %%
categorical_features = ['Brand', 'Processor_Name', 'Processor_Brand', 'RAM_Expandable', 'RAM_TYPE', 'Display_type', 'GPU', 'GPU_Brand', 'Battery_Life']
categorical_unique_values = {}
for col in categorical_features:
    # Handle potential NaN values by converting to string or dropping them before getting unique values
    if df[col].isnull().any():
        categorical_unique_values[col] = df[col].dropna().astype(str).unique().tolist()
    else:
        categorical_unique_values[col] = df[col].astype(str).unique().tolist()

print("Unique values for categorical features:")
for col, values in categorical_unique_values.items():
    print(f"{col}: {values}")
# Out:
# Unique values for categorical features:
# Brand: ['HP', 'Lenovo', 'Dell', 'Infinix', 'Acer', 'ASUS', 'Tecno', 'Xiaomi', 'MSI', 'Samsung', 'Apple', 'Realme', 'AVITA', 'Zebronics', 'Honor', 'Fujitsu', 'Wings', 'LG', 'Gigabyte', 'Microsoft', 'Razer', 'Coconics', 'Huawei', 'Micromax', 'iball', 'Lava', 'VAIO', 'Smartron', 'Colorful', 'Nokia', 'RDP']
# ...

# %%
numerical_features = ['RAM', 'Ghz', 'Display', 'SSD', 'HDD', 'Adapter']
numerical_min_max_values = {}
for col in numerical_features:
    numerical_min_max_values[col] = {
        'min': df[col].min(),
        'max': df[col].max()
    }

print("Min/Max values for numerical features:")
for col, values in numerical_min_max_values.items():
    print(f"{col}: Min={values['min']}, Max={values['max']}")
# Out:
# Min/Max values for numerical features:
# RAM: Min=2, Max=64
# Ghz: Min=0.0, Max=5.5
# Display: Min=10.100000381469727, Max=18.0
# SSD: Min=0, Max=4098
# HDD: Min=0, Max=2048
# Adapter: Min=15, Max=330

# %%
from ipywidgets import widgets, Layout
from IPython.display import display

# Create a dictionary to hold all the widgets
all_widgets = {}

# Create widgets for categorical features
for col in categorical_features:
    options = categorical_unique_values[col]
    # If the list of options is empty or contains only None/NaN, use a default option
    if not options or (len(options) == 1 and options[0] is None):
        options = ['N/A']
        default_value = 'N/A'
    else:
        default_value = options[0]

    all_widgets[col] = widgets.Dropdown(
        options=options,
        value=default_value,
        description=col + ':',
        disabled=False,
        layout=Layout(width='auto')
    )

# Create widgets for numerical features
for col in numerical_features:
    min_val = numerical_min_max_values[col]['min']
    max_val = numerical_min_max_values[col]['max']

    if col in ['RAM', 'SSD', 'HDD', 'Adapter']:
        # Ensure min_val and max_val are integers for IntSlider
        min_val = int(min_val) if pd.notna(min_val) else 0
        max_val = int(max_val) if pd.notna(max_val) else 100
        default_val = int((min_val + max_val) / 2)
        step = 1
        all_widgets[col] = widgets.IntSlider(
            min=min_val,
            max=max_val,
            step=step,
            value=default_val,
            description=col + ':',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True,
            readout_format='d',
            layout=Layout(width='auto')
        )
    elif col in ['Ghz', 'Display']:
        # Ensure min_val and max_val are floats for FloatSlider
        min_val = float(min_val) if pd.notna(min_val) else 0.0
        max_val = float(max_val) if pd.notna(max_val) else 20.0
        default_val = float((min_val + max_val) / 2)
        step = 0.1
        all_widgets[col] = widgets.FloatSlider(
            min=min_val,
            max=max_val,
            step=step,
            value=default_val,
            description=col + ':',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True,
            readout_format='.1f',
            layout=Layout(width='auto')
        )

# Display all widgets
for col, widget in all_widgets.items():
    print(f"--- {col} ---")
    display(widget)
# Out:
# --- Brand ---
# Dropdown(description='Brand:', layout=Layout(width='auto'), options=('HP', 'Lenovo', 'Dell', 'Infinix', 'Acer'…
# --- Processor_Name ---
# Dropdown(description='Processor_Name:', layout=Layout(width='auto'), options=('MediaTek Octa-core', 'AMD Hexa-…
# --- Processor_Brand ---
# Dropdown(description='Processor_Brand:', layout=Layout(width='auto'), options=('MediaTek', 'AMD', 'Intel', 'Ap…
# --- RAM_Expandable ---
# Dropdown(description='RAM_Expandable:', layout=Layout(width='auto'), options=('Not Expandable', ' 12 GB Expand…
# --- RAM_TYPE ---
# Dropdown(description='RAM_TYPE:', layout=Layout(width='auto'), options=(' DDR4 RAM', ' DDR4 RAM ', ' DDR5 RAM …
# --- Display_type ---
# Dropdown(description='Display_type:', layout=Layout(width='auto'), options=('LED', 'LCD'), value='LED')
# --- GPU ---
# Dropdown(description='GPU:', layout=Layout(width='auto'), options=('Integrated Graphics', 'Radeon', 'GeForce R…
# --- GPU_Brand ---
# ...

# %%
def predict_price_interactive(**kwargs):
    # Create a DataFrame from the widget values
    input_data = pd.DataFrame({
        'Brand': [kwargs['Brand']],
        'Name': ['Dummy Name'], # 'Name' is not used in prediction pipeline, so a placeholder is fine
        'Processor_Name': [kwargs['Processor_Name']],
        'Processor_Brand': [kwargs['Processor_Brand']],
        'RAM_Expandable': [kwargs['RAM_Expandable']],
        'RAM': [kwargs['RAM']],
        'RAM_TYPE': [kwargs['RAM_TYPE']],
        'Ghz': [kwargs['Ghz']],
        'Display_type': [kwargs['Display_type']],
        'Display': [kwargs['Display']],
        'GPU': [kwargs['GPU']],
        'GPU_Brand': [kwargs['GPU_Brand']],
        'SSD': [kwargs['SSD']],
        'HDD': [kwargs['HDD']],
        'Adapter': [kwargs['Adapter']],
        'Battery_Life': [kwargs['Battery_Life']]
    })

    # Make prediction
    predicted_log_price = pipe.predict(input_data)
    predicted_price = np.exp(predicted_log_price)

    print(f"Predicted Laptop Price: ₹{predicted_price[0]:,.2f}")

# Create an interactive output widget
output_widget = widgets.Output()

# Link widgets to the prediction function
interactive_prediction = widgets.interactive(predict_price_interactive, **all_widgets)

# Display the interactive UI
display(interactive_prediction)
# Out:
# Predicted Laptop Price: ₹100,365.14
